# %% [markdown]
# # Welcome to Jupyter!

# %%
life = 10 
print("Hi!")
name = input("What is your name?: ")
print("Welcome",name,)
print("Are you ready to go on a mission to save the planet?")
Answer_1 = input("(yes/no): ")
if Answer_1 == 'yes':
    print("Your name is",name,"Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions to destroy the pollutarians. These are evil monsters who want to destroy the world by tricking you into giving the wrong answer. Good luck on your mission.")
else:
    print("Alright,see you next time!")
AllQuestions = ['Which city is more polluted? \ntype 1. for Hotan, China \ntype 2. for Berlin,Germany', 'What is the most common type of garbage that litters in our ocean? \ntype 1. for food packaging \ntype 2. for cigarettes', 'Do you think that it is a good idea to use shared transport options and turn off the heater to save energy? \ntype yes or no', 'Which of the following sources of energy is not renewable? \nA. Petroleum \nB. Hydro power \nC. Biomass \nD. Solar power \ntype A, B, C, or D', 'Decide, what´s the definition of the carbon footprint. \nIs it either A: The total amount of greenhouse gases, that are generated by our actions. \nOr B: The total amount of greeenhouse gases generated by animals \ntype A or B', '30% of the planet´s land is covered by forest? \ntype true or false', 'The reason for the occurrence of acid rain is pollution by acid, that has been released into the atmosphere? \ntype true or false', 'What country produces the most energy in the world? \nA. China \nB. Norway \ntype A or B', 'How much of the world´s water is available for human use? \nA. 23% \nB. less than 1%\nC. 97% \nD. 50% \ntype A, B, C, or D', 'According to the World Health Organisation New Delhi is the most polluted city in the world \ntype true or false', 'What is the most common type of trash thrown away by Americans? \nA. paper products and cardboard \nB. metals \nC. glass \nD. plastic \ntype A, B, C, or D']

class Q1:
    def answer1():
        return "Very good!"
    def answer2():
        return "You are wrong!"
            
class Q2:
    def question_yesno(self, answer1):
        self.answer1 = answer1
        answer1(AllQuestions[2])
        answer1(AllQuestions[9])
class Q3:
    def question_open(self, answer2):
        self.answer2 = answer2
        answer2(AllQuestions[3])
class Q4:
    def question_ABCD(self, answer3):
        self.answer3 = answer3
        answer3(AllQuestions[4])
        answer3(AllQuestions[6])
        answer3(AllQuestions[7])
        answer3(AllQuestions[10])
        answer3(AllQuestions[15])
        answer3(AllQuestions[16])
class Q5:
    def question_truefalse(self, answer4):
        self.answer4 = answer4
        answer4(AllQuestions[5])
        answer4(AllQuestions[8])
        answer4(AllQuestions[12])
        answer4(AllQuestions[13])
        answer4(AllQuestions[16])
class Q6:
    def question_AB(self, answer5):
        answer5(AllQuestions[11])
        answer5(AllQuestions[14])

# %%
print("You are on your mission and after a short period of time you come across the first challenge: a huge wall. To successfully overcome the barrier you have to answer the following question correctly.")
print("But be careful, you only have 10 lives and every mistake costs you one of them.")

# %%
print (AllQuestions[0])
a = Q1.answer1()
b = Q1.answer2()
Answer = input()
if Answer == '1':
    print (a)
else:
    print (b)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true'), width=597, height=357)
# Out:
# Which city is more polluted?
# type 1. for Hotan, China
# type 2. for Berlin,Germany
# 1
# Very good!

# %%
print (AllQuestions[2])

# %%
print("Which city is more polluted?")
print("type 1. for Hotan, China \ntype 2. for Berlin,Germany")
Answer_2 = input()

if Answer_2 == '1':
    print("You are right.\nSuddenly, the wall comes alive and spits out a leather. With its help you are able to surmount the wall.")
else:
    print("What a pity! You lost your first life.")
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true'), width=597, height=357)

# %%
print("Is it true that Germany has the most power plants worldwide?")
Answer_3 = input("(yes/no): ")

if Answer_3 == 'no':
    print("Well done, you are a true expert.")
else:
    print("That is too bad, your answer is incorrect. You lost a life..")
    print("Remaining lives:",life - 1,)

# %%
print("Which country is known as the land of windmills")
Answer_4 = input(":  ")

if Answer_4 == 'The Netherlands'or 'the Netherlands' or 'Holland':
    print("That was the correct answer!")
else:
    print("Oh no!")
    print("Remaining lives:",life - 1,)

# %%
print("What country consumes the most energy in the world?")
print("A. Russia \nB. China \nC.United States \nD. Canada")
Answer_5 = input("type A, B, C, or D:  ")

if Answer_5 == 'C':
    print("Wonderful!")
else:
    print("Ops! Wrong answer!")
    print("Remaining lives:",life - 1,)

# %%
print("Is China the country that produces the most solar power?")
print("true/false")
Answer_6 = input("type true or false:  ")

if Answer_6 == 'true':
    print("Good job!")
else:
    print("You still have a lot to learn!")
    print("Remaining lives",life - 1,)

# %%
print("Which of the following materials can be recovered from the recycling of soft drink cans?")
print("A. glass \nB. metal \nC. paper \nD. plastic")
Answer_7 = input("type A, B, C, or D:  ")

if Answer_7 == 'B':
    print("Great, you did amazing!")
else:
    print("What a pity! Maybe next time.")
    print("Remaining lives:",life - 1,)

# %%
print("What is the greenest country in the world?")
print("A. Afghanistan \nB. Russia \nC. USA \nD. Denmark")
Answer_8 = input("type A, B, C, or D:  ")

if Answer_8 == 'D':
    print("Wow, you know a lot!")
else:
    print("You failed... ")
    print("Remaining lives:",life - 1,)

# %%
print("Is the long-term temperature goal of the Paris Agreement is 1.5-2.0 degrees?")
print("true/false")
Answer_9 = input("type true or false:  ")

if Answer_9 == 'true':
    print("Well done!")
else:
    print("Don´t give up!")
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[1])
Answer_1 = input()
if Answer_1 == '2':
    print (a)
else:
    print (b)
# Out:
# What is the most common type of garbage that litters in our ocean? n	ype 1. for food packaging
# type 2. for cigarettes
# 2
# Very good!

# %%
print("Do you think that it is a good idea to use shared transport options and turn off the heater to save energy?")
print("yes/no")
Answer_11 = input("type yes or no  ")

if Answer_11 == 'yes':
    print("Hurrah, congratulation!")
else:
    print("That´s too bad!")
    print("Remaining lives",life - 1,)

# %%
print("Which of the following sources of energy is not renewable?")
print("A. Petroleum \nB. Hydro power \nC. Biomass \nD. Solar power")
Answer_12 = input("type A, B, C, or D:  ")

if Answer_12 == 'A':
    print("You are too smart for this quiz!")
else:
    print("It´s not your fault, it´s ours...")
    print("Remaining lives:",life - 1,)

# %%
print("Decide, what´s the definition of the carbon footprint. Is it either A: The total amount of greenhouse gases, that are generated by our actions. Or B: The total amount of greeenhouse gases generated by animals.")
print("A. generated by our actions \nB. generated by animals")
Answer_13 = input("type A or B:  ")

if Answer_13 == 'B':
    print("Are a you a genius?")
else:
    print("What? There must be some sort of technical issue.")
    print("Remaining lives:",life - 1,)

# %%
print("30% of the planet´s land is covered by forest?")
print("true/false")
Answer_14 = input("type true or false:  ")

if Answer_14 == 'true':
    print("Seems like you are cheating!")
else:
    print("You should have used Google!")
    print("Remaining lives",life - 1,)

# %%
print("The reason for the occurrence of acid rain is pollution by acid, that has been released into the atmosphere?")
print("true/false")
Answer_15 = input("type true or false:  ")

if Answer_15 == 'true':
    print("You really can´t be fooled!")
else:
    print("And again, you lost a life!")
    print("Remaining lives",life - 1,)

# %%
print("What country produces the most energy in the world?")
print("A. China \nB. Norway")
Answer_16 = input("type A or B:  ")

if Answer_16 == 'A':
    print("You probably always got straight A´s in school.")
else:
    print("You should have learned more.")
    print("Remaining lives:",life - 1,)

# %%
print("How much of the world´s water is available for human use?")
print("A. 23% \nB. less than 1%\ nC. 97% \ nD. 50%")
Answer_17= input("type A, B, C, or D:  ")

if Answer_17 = 'B':
    print("You are a pro!")
else:
    print("That´s wrong. Only about one third of 1% of all water on earth is available for human use")
    print("Remaining lives:",life - 1,)

# %%
print("According to the World Health Organisation New Delhi is the most polluted city in the world")
print("true/false")
Answer_18 = input("type true or false:  ")

if Answer_18 == 'false':
    print("You are such a geek!")
else:
    print("No, actually it is Mexco City!")
    print("Remaining lives",life - 1,)

# %%
print("What is the most common type of trash thrown away by Americans?")
print("A. paper products and cardboard \nB. metals \ nC. glass \ nD. plastic")
Answer_19= input("type A, B, C, or D:  ")

if Answer_19 == 'A':
    print("Great, you made it to the end!")
else:
    print("At least you are done.")
    print("Remaining lives:",life - 1,)
