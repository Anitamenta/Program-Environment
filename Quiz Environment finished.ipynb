# %% [markdown]
# # Welcome to the "Quiz about the Environment"

# %%
life = 10 
print("Hi!")
name = input("What is your name?: ")
print("Welcome",name,)
print("Are you ready to go on a mission to save the planet?")
Answer_1 = input("(yes/no): ")
if Answer_1 == 'yes':
    print("Your name is",name,"Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions. If you answer correctly you will gain points, which will enable you to fulfill your mission.")
else:
    print("Alright,see you next time!")
AllQuestions = ['Which city is more polluted? \nType 1. for Hotan, China \nType 2. for Berlin,Germany', 
                'What is the most common type of garbage that litters in our ocean? \nType 1. for food packaging \nType 2. for cigarettes', 
                'Is it true that Germany has the most nuclear power plants worldwide? \nType yes or no.',
                'How many people per year die due to the damages or pollution?',
                'What country consumes the most energy in the world? \nA. Russia \nB. China \nC. United States \nD. Canada \nType A, B, C or D',
                'Is China the country that produces the most solar power? \nType true or false.',
                'Which of the following materials is recycled the most? \nA. glass \nB. metal \nC. paper \nD. plastic \nType A, B, C or D',
                'What is the greenest country in the world? \nA. Afghanistan \nB. Russia \nC. USA \nD. Denmark \nType A, B, C or D',
                'Is the long-term temperature goal of the Paris Agreement 1.5-2.0 degrees? \nType true or false.',
                'How much of the total pollution is caused by cars emissions? \nA. 30% \nB. 60.7% \nC. 80.2% \nD. 45% \nType A, B, C or D', 
                'Which of the following sources of energy is not renewable? \nA. Petroleum \nB. Hydro power \nC. Biomass \nD. Solar power \nType A, B, C, or D', 
                'Decide, what´s the definition of the carbon footprint. \nIs it either \nA: The total amount of greenhouse gases, that are generated by our actions. \nOr B: The total amount of greeenhouse gases generated by animals. \nType A or B', 
                '30% of the planet´s land is covered by forest. \nType true or false.', 
                'The reason for the occurrence of acid rain is pollution by acid, that has been released into the atmosphere. \nType true or false.', 
                'What country produces the most energy in the world? \nA. China \nB. Norway \nType A or B', 
                'How much of the world´s water is available for human use? \nA. 23% \nB. less than 1%\nC. 97% \nD. 50% \nType A, B, C, or D', 
                'According to the World Health Organisation New Delhi is the most polluted city in the world this year. \nType true or false.', 
                'What is the most common type of trash thrown away by Americans? \nA. paper products and cardboard \nB. metals \nC. glass \nD. plastic \nType A, B, C, or D']

class Q1:
    def answer1():
        return "Very good!"
    def answer2():
        return "You are wrong!"
    def answer3():
        return "Well done!"
    def answer4():
        return "Your answer is wrong."
    def answer5():
        return "That was the correct answer!"
    def answer6():
        return "Oh no!"
    def answer7():
        return "Wonderful!"
    def answer8():
        return "Ops! Wrong answer!"
    def answer9():
        return "Great!"
    def answer10():
        return "What a pity, it is wrong!"
    def answer11():
        return "You are a pro!"
    def answer12():
        return "Sorry, that is not the right choice!"
    def answer13():
        return "Good job!"
    def answer14():
        return "You still have something to learn!"
    def answer15():
        return "You are right!"
    def answer16():
        return "Wrong, but don't give up!"
    def answer17():
        return "Hurrah, congratulations!"
    def answer18():
        return "You can always try again!"
    def answer19():
        return "WoW! Really good."
    def answer20():
        return "Oh no! You lost a life!"
    
a = Q1.answer1()
b = Q1.answer2()
c = Q1.answer3()
d = Q1.answer4()
e = Q1.answer5()
f = Q1.answer6()
g = Q1.answer7()
h = Q1.answer8()
i = Q1.answer9()
j = Q1.answer10()
k = Q1.answer11()
l = Q1.answer12()
m = Q1.answer13()
n = Q1.answer14()
o = Q1.answer15()
p = Q1.answer16()
q = Q1.answer17()
r = Q1.answer18()
s = Q1.answer19()
t = Q1.answer20()
# Out:
# Hi!
# What is your name?: Anita
# Welcome Anita
# Are you ready to go on a mission to save the planet?
# (yes/no): yes
# Your name is Anita Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions. If you answer correctly you will gain points, which will enable you to fulfill your mission.

# %%
print (AllQuestions[0])
Answer = input()
if Answer == '1':
    print (a)
else:
    print (b)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true'), width=597, height=357)
# Out:
# Which city is more polluted?
# Type 1. for Hotan, China
# Type 2. for Berlin,Germany
# 1
# Very good!
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true" width="597" height="357"/>

# %%
print (AllQuestions[2])
Answer_2 = input()
if Answer_2 == 'no':
    print (c)
else:
    print (d)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%202021-06-21%20085715.png?raw=true'))
# Out:
# Is it true that Germany has the most nuclear power plants worldwide?
# Type yes or no.
# no
# Well done!
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%202021-06-21%20085715.png?raw=true"/>

# %%
print (AllQuestions[3])
Answer_3 = input()
if Answer_3 == '7 million' or '7,000,000' or 'seven million':
    print (e)
else:
    print (f)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://cdn.shortpixel.ai/spai/w_1003+q_glossy+ret_img+to_webp/https://balkangreenenergynews.com/wp-content/uploads/2020/12/Air-pollution-premature-deaths-WHO.jpg'), width=597, height=357)
# Out:
# How many people per year die due to the damages or pollution?
# 7 million
# That was the correct answer!
# <img src="https://cdn.shortpixel.ai/spai/w_1003+q_glossy+ret_img+to_webp/https://balkangreenenergynews.com/wp-content/uploads/2020/12/Air-pollution-premature-deaths-WHO.jpg" width="597" height="357"/>

# %%
print (AllQuestions[4])
Answer_4 = input()
if Answer_4 == 'C':
    print (g)
else:
    print (h)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%202.png?raw=true'), width=597, height=357)
# Out:
# What country consumes the most energy in the world?
# A. Russia
# B. China
# C. United States
# D. Canada
# Type A, B, C or D
# a
# Ops! Wrong answer!
# Remaining lives: 9
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%202.png?raw=true" width="597" height="357"/>

# %%
print (AllQuestions[5])
Answer_5 = input()
if Answer_5 == 'true':
    print (i)
else: 
    print (j)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://solaredition.com/wp-content/uploads/2020/03/Top-10-Countries-in-Solar-Electricity-Generation-678x381.png'))
# Out:
# Is China the country that produces the most solar power?
# Type true or false.
# true
# Great!
# <img src="https://solaredition.com/wp-content/uploads/2020/03/Top-10-Countries-in-Solar-Electricity-Generation-678x381.png"/>

# %%
print (AllQuestions[6])
Answer_6 = input()
if Answer_6 == 'C':
    print (a)
else:
    print (b)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://cen.acs.org/content/dam/cen/97/39/WEB/09739-cover-linegraph.jpg'), width=597, height=357)
# Out:
# Which of the following materials is recycled the most?
# A. glass
# B. metal
# C. paper
# D. plastic
# Type A, B, C or D
# C
# Very good!
# <img src="https://cen.acs.org/content/dam/cen/97/39/WEB/09739-cover-linegraph.jpg" width="597" height="357"/>

# %%
print (AllQuestions[7])
Answer_7 = input()
if Answer_7 == 'D':
    print (k)
else:
    print (l)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%203.png?raw=true'))
# Out:
# What is the greenest country in the world?
# A. Afghanistan
# B. Russia
# C. USA
# D. Denmark
# Type A, B, C or D
# A
# Sorry, that is not the right choice!
# Remaining lives 9
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/Screenshot%203.png?raw=true"/>

# %%
print (AllQuestions[8])
Answer_8 = input()
if Answer_8 == 'true':
    print (m)
else:
    print (n)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://climateactiontracker.org/media/images/CAT-Thermometer-2020.12-3BarsText-Transparent.original.png'), width=700, height=600)
# Out:
# Is the long-term temperature goal of the Paris Agreement 1.5-2.0 degrees?
# Type true or false.
# true
# Good job!
# <img src="https://climateactiontracker.org/media/images/CAT-Thermometer-2020.12-3BarsText-Transparent.original.png" width="700" height="600"/>

# %%
print (AllQuestions[1])
Answer_1 = input()
if Answer_1 == '2':
    print (a)
else:
    print (b)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://pbs.twimg.com/media/EE8_4EQWkAAuLAE.png'))
# Out:
# What is the most common type of garbage that litters in our ocean?
# Type 1. for food packaging
# Type 2. for cigarettes
# 2
# Very good!
# <img src="https://pbs.twimg.com/media/EE8_4EQWkAAuLAE.png"/>

# %%
print (AllQuestions[9])
Answer_9 = input()
if Answer_9 == 'B':
    print (o)
else:
    print (p)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://www.europarl.europa.eu/resources/library/images/20190507PHT44958/20190507PHT44958-cl.jpg'), width=597, height=357)
# Out:
# How much of the total pollution is caused by cars emissions?
# A. 30%
# B. 60.7%
# C. 80.2%
# D. 45%
# Type A, B, C or D
# B
# You are right!
# <img src="https://www.europarl.europa.eu/resources/library/images/20190507PHT44958/20190507PHT44958-cl.jpg" width="597" height="357"/>

# %%
print (AllQuestions[10])
Answer_10 = input()
if Answer_10 == 'A':
    print (c)
else:
    print (d)
    print("Remaining lives",life - 1,)
print ('Petroleum, being a fossil fuel, is a scarce resource with high global demand. As a result, petroleum prices keep hiking as some oil wells dry out. Recent statistics indicated that we have already utilized over half of the oil reserves in the world.')
# Out:
# Which of the following sources of energy is not renewable?
# A. Petroleum
# B. Hydro power
# C. Biomass
# D. Solar power
# Type A, B, C, or D
# A
# Well done!
# Petroleum, being a fossil fuel, is a scarce resource with high global demand. As a result, petroleum prices keep hiking as some oil wells dry out. Recent statistics indicated that we have already utilized over half of the oil reserves in the world.

# %%
print (AllQuestions[11])
Answer_11 = input()
if Answer_11 == 'A':
    print (q)
else:
    print (r)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://cdn.thinglink.me/api/image/565153314732244993/1024/10/scaletowidth/0/0/1/1/false/true?wait=true'), width=396, height=424)
# Out:
# Decide, what´s the definition of the carbon footprint.
# Is it either
# A: The total amount of greenhouse gases, that are generated by our actions.
# Or B: The total amount of greeenhouse gases generated by animals.
# Type A or B
# B
# You can always try again!
# Remaining lives 9
# <img src="https://cdn.thinglink.me/api/image/565153314732244993/1024/10/scaletowidth/0/0/1/1/false/true?wait=true" width="396" height="424"/>

# %%
print (AllQuestions[12])
Answer_12 = input()
if Answer_12 == 'true':
    print (e)
else:
    print (f)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://www.reforestationworld.org/sites/default/files/UNEP-global_forest_cover_change-original-2000.png'))
# Out:
# 30% of the planet´s land is covered by forest.
# Type true or false.
# true
# That was the correct answer!
# <img src="https://www.reforestationworld.org/sites/default/files/UNEP-global_forest_cover_change-original-2000.png"/>

# %%
print (AllQuestions[13])
Answer_13 = input()
if Answer_13 == 'true':
    print (s)
else:
    print (t)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('http://acidrainawscience.weebly.com/uploads/2/6/7/9/26794501/6949893.gif?531'))
# Out:
# The reason for the occurrence of acid rain is pollution by acid, that has been released into the atmosphere
# Type true or false.
# yes
# Oh no! You lost a life!
# Remaining lives 9
# <img src="http://acidrainawscience.weebly.com/uploads/2/6/7/9/26794501/6949893.gif?531"/>

# %%
print (AllQuestions[14])
Answer_14 = input()
if Answer_14 == 'A':
    print(i)
else: 
    print (j)
    print("Remaining lives",life - 1,)
print ('Trends for most energy produced have generally mimicked energy used at the top of the list i.e. China has overtaken the US in the recent decades. \nOther countries producing the most energy behind the US and China include Russia, Saudi Arabia, Canada, Indonesia, India, Iran, Australia and Qatar.')
# Out:
# What country produces the most energy in the world?
# A. China
# B. Norway
# Type A or B
# A
# Great!
# Trends for most energy produced have generally mimicked energy used at the top of the list i.e. China has overtaken the US in the recent decades.
# Other countries producing the most energy behind the US and China include Russia, Saudi Arabia, Canada, Indonesia, India, Iran, Australia and Qatar.

# %%
print (AllQuestions[15])
Answer_15 = input()
if Answer_15 == 'B':
    print (m)
else:
    print (n)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://prod-media.coolaustralia.org/wp-content/uploads/2013/05/06193500/water-quantity.jpg'), width=700, height=450)
# Out:
# How much of the world´s water is available for human use?
# A. 23%
# B. less than 1%
# C. 97%
# D. 50%
# Type A, B, C, or D
# B
# Good job!
# <img src="https://prod-media.coolaustralia.org/wp-content/uploads/2013/05/06193500/water-quantity.jpg" width="700" height="450"/>

# %%
print (AllQuestions[16])
Answer_16 = input()
if Answer_16 == 'true':
    print (s)
else:
    print (t)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/world_en.png?raw=true'))
# Out:
# According to the World Health Organisation New Delhi is the most polluted city in the world this year.
# Type true or false.
# true
# WoW! Really good.
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/world_en.png?raw=true"/>

# %%
print (AllQuestions[17])
Answer_17 = input()
if Answer_17 == 'A':
    print (o)
else:
    print (r)
    print("Remaining lives",life - 1,)
from IPython.display import Image
Image(url=('http://4.bp.blogspot.com/_lci5hAqtFVk/S0pNXZ_2XvI/AAAAAAAACf8/Sp_R37xuijI/s400/food+scrap+chart.jpg'), width=460, height=468)
# Out:
# What is the most common type of trash thrown away by Americans?
# A. paper products and cardboard
# B. metals
# C. glass
# D. plastic
# Type A, B, C, or D
# A
# You are right!
# <img src="http://4.bp.blogspot.com/_lci5hAqtFVk/S0pNXZ_2XvI/AAAAAAAACf8/Sp_R37xuijI/s400/food+scrap+chart.jpg" width="460" height="468"/>

# %%
print ('You reached the end of your mission!')
print('Thank you for playing! We hope that you have learned something new about the environment and have realised why it is so important to take care of it! \nBye bye')
# Out:
# You reached the end of your mission!
# Thank you for playing! We hope that you have learned something new about the environment and have realised why it is so important to take care of it!
# Bye bye
