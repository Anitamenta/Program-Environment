# %% [markdown]
# # Welcome to Jupyter!

# %%
life = 10 
print("Hi!")
name = input("What is your name?: ")
print("Welcome",name,)
print("Are you ready to go on a mission to save the planet?")
Answer_1 = input("(yes/no): ")
if Answer_1 == 'yes':
    print("Your name is",name,"Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions. If you answer correctly you will gain points, which will enable you to fulfill your mission.")
else:
    print("Alright,see you next time!")
AllQuestions = ['Which city is more polluted? \nType 1. for Hotan, China \nType 2. for Berlin,Germany', 
                'What is the most common type of garbage that litters in our ocean? \nType 1. for food packaging \nType 2. for cigarettes', 
                'Is it true that Germany has the most power plants worldwide? \nType yes or no',
                'How many people per year die due to the damages or pollution?',
                'What country consumes the most energy in the world? \nA. Russia \nB. China \nC. United States \nD. Canada \nType A, B, C or D',
                'Is China the country that produces the most solar power? \nType true or false',
                'Which of the following materials can be recovered from the recycling of soft drink cans? \nA. glass \nB. metal \nC. paper \nD. plastic \nType A, B, C or D',
                'What is the greenest country in the world? \nA. Afghanistan \nB. Russia \nC. USA \nD. Denmark \nType A, B, C or D',
                'Is the long-term temperature goal of the Paris Agreement 1.5-2.0 degrees? \nType true or false',
                'Do you think that it is a good idea to use shared transport options and turn off the heater to save energy? \nType yes or no', 
                'Which of the following sources of energy is not renewable? \nA. Petroleum \nB. Hydro power \nC. Biomass \nD. Solar power \nType A, B, C, or D', 
                'Decide, what´s the definition of the carbon footprint. \nIs it either \nA: The total amount of greenhouse gases, that are generated by our actions. \nOr B: The total amount of greeenhouse gases generated by animals. \nType A or B', 
                '30% of the planet´s land is covered by forest \nType true or false', 
                'The reason for the occurrence of acid rain is pollution by acid, that has been released into the atmosphere \nType true or false', 
                'What country produces the most energy in the world? \nA. China \nB. Norway \nType A or B', 
                'How much of the world´s water is available for human use? \nA. 23% \nB. less than 1%\nC. 97% \nD. 50% \nType A, B, C, or D', 
                'According to the World Health Organisation New Delhi is the most polluted city in the world \nType true or false', 
                'What is the most common type of trash thrown away by Americans? \nA. paper products and cardboard \nB. metals \nC. glass \nD. plastic \nType A, B, C, or D']

class Q1:
    def answer1():
        return "Very good!"
    def answer2():
        return "You are wrong!"
    def answer3():
        return "Well done!"
    def answer4():
        return "Your answer is wrong."
    def answer5():
        return "That was the correct answer!"
    def answer6():
        return "Oh no!"
    def answer7():
        return "Wonderful!"
    def answer8():
        return "Ops! Wrong answer!"
    def answer9():
        return "Great!"
    def answer10():
        return "What a pity, it is wrong!"
    def answer11():
        return "You are a pro!"
    def answer12():
        return "Sorry, that is not the right choice!"
    def answer13():
        return "Good job!"
    def answer14():
        return "You still have something to learn!"
    def answer15():
        return "You are right!"
    def answer16():
        return "Wrong, but don't give up!"
    def answer17():
        return "Hurrah, congratulations!"
    def answer18():
        return "You can always try again!"
    def answer19():
        return "WoW! Really good."
    def answer20():
        return "Oh no! You lost a life!"
    
a = Q1.answer1()
b = Q1.answer2()
c = Q1.answer3()
d = Q1.answer4()
e = Q1.answer5()
f = Q1.answer6()
g = Q1.answer7()
h = Q1.answer8()
i = Q1.answer9()
j = Q1.answer10()
k = Q1.answer11()
l = Q1.answer12()
m = Q1.answer13()
n = Q1.answer14()
o = Q1.answer15()
p = Q1.answer16()
q = Q1.answer17()
r = Q1.answer18()
s = Q1.answer19()
t = Q1.answer20()
# Out:
# Hi!
# What is your name?: Anita
# Welcome Anita
# Are you ready to go on a mission to save the planet?
# (yes/no): yes
# Your name is Anita Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions to destroy the pollutarians. These are evil monsters who want to destroy the world by tricking you into giving the wrong answer. Good luck on your mission.

# %%
print (AllQuestions[0])
Answer = input()
if Answer == '1':
    print (a)
else:
    print (b)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true'), width=597, height=357)
# Out:
# Which city is more polluted?
# Type 1. for Hotan, China
# Type 2. for Berlin,Germany
# 1
# Very good!
# <img src="https://github.com/Anitamenta/Program-Environment/blob/main/image.jpg?raw=true" width="597" height="357"/>

# %%
print (AllQuestions[2])
Answer_2 = input()
if Answer_2 == 'no':
    print (c)
else:
    print (d)
    print("Remaining lives:",life - 1,)

# %%
print (AllQuestions[3])
Answer_3 = input()
if Answer_3 == 'The Netherlands'or 'the Netherlands' or 'Holland':
    print (e)
else:
    print (f)
    print("Remaining lives:",life - 1,)
from IPython.display import Image
Image(url=('https://cdn.shortpixel.ai/spai/w_1003+q_glossy+ret_img+to_webp/https://balkangreenenergynews.com/wp-content/uploads/2020/12/Air-pollution-premature-deaths-WHO.jpg'))

# %%
print (AllQuestions[4])
Answer_4 = input()
if Answer_4 == 'C':
    print (g)
else:
    print (h)
    print("Remaining lives:",life - 1,)

# %%
print (AllQuestions[5])
Answer_5 = input()
if Answer_5 == 'true':
    print (i)
else: 
    print (j)
    print("Remaining lives:",life - 1,)

# %%
print (AllQuestions[6])
Answer_6 = input()
if Answer_6 == 'B':
    print (a)
else:
    print (b)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[7])
Answer_7 = input()
if Answer_7 == 'D':
    print (k)
else:
    print (l)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[8])
Answer_8 = input()
if Answer_8 == 'true':
    print (m)
else:
    print (n)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[1])
Answer_1 = input()
if Answer_1 == '2':
    print (a)
else:
    print (b)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[9])
Answer_9 = input()
if Answer_9 == 'yes':
    print (o)
else:
    print (p)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[10])
Answer_10 = input()
if Answer_10 == 'A':
    print (c)
else:
    print (d)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[11])
Answer_11 = input()
if Answer_11 == 'B':
    print (q)
else:
    print (r)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[12])
Answer_12 = input()
if Answer_12 == 'true':
    print (e)
else:
    print (f)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[13])
Answer_13 = input()
if Answer_13 == 'true':
    print (s)
else:
    print (t)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[14])
Answer_14 = input()
if Answer_14 == 'A':
    print(i)
else: 
    print (j)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[15])
Answer_15 = input()
if Answer_15 == 'B':
    print (m)
else:
    print (n)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[16])
Answer_16 = input()
if Answer_16 == 'false':
    print (s)
else:
    print (t)
    print("Remaining lives",life - 1,)

# %%
print (AllQuestions[17])
Answer_17 = input()
if Answer_17 == 'A':
    print (o)
else:
    print (r)
    print("Remaining lives",life - 1,)
