# %% [markdown]
# # Welcome to Jupyter!

# %%
print ("let us start the game")
let_us_start_the_game = input("Are you ready? (yes/no): ")

if let_us_start_the_game == 'yes':
    print("Your name is Elian Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions to destroy the pollutarians. These are evil monsters who want to destroy the world by tricking you into giving the wrong answer. Good luck on your mission.")
else:
    print("Alright,see you next time!")
print("You are on your mission and after a short period of time you come across the first challenge: a huge wall. To successfully overcome the barrier you have to answer the following question correctly.")
print("But be careful, you only have 10 lives and every mistake costs you one of them.")
# Out:
# let us start the game
# Are you ready? (yes/no): yes
# Your name is Elian Byte and you are on a mission to save our world from environmental damage. To achieve your goal you have to answer different questions to destroy the pollutarians. These are evil monsters who want to destroy the world by tricking you into giving the wrong answer. Good luck on your mission.
# You are on your mission and after a short period of time you come across the first challenge: a huge wall. To successfully overcome the barrier you have to answer the following question correctly.
# But be careful, you only have 10 lives and every mistake costs you one of them.

# %%
print("Which city is more polluted?")
Which_city_is_more_polluted = input("What would you say? Type 1 for Hutan, China and 2 for Berlin, Germany (Hutan, China/Berlin, Germany): ")
print("type 1 for Hutan, China and 2 for Berlin,Germany")
"Hutan, China"=="1"
"Berlin, Germany" =="2"
if Which_city_is_more_polluted == '1':
    print("You are right. Suddenly, the wall comes alive and spits out a leather. With its help you are able to surmount the wall.")
else:
    print("What a pity! You lost your first life.")
# Out:
# Which city is more polluted?
# What would you say? Type 1 for Hutan, China and 2 for Berlin, Germany (Hutan, China/Berlin, Germany): 1
# type 1 for Hutan, China and 2 for Berlin,Germany
# You are right. Suddenly, the wall comes alive and spits out a leather. With its help you are able to surmount the wall.

# %%
print("Is it true that Germany has the most power plants worldwide?")
Is_it_true_that_Germany_has_the_most_power_plants_worldwide = input("What would you say? (yes/no): ")

if Is_it_true_that_Germany_has_the_most_power_plants_worldwide == 'yes':
    print("Well done, you are a true expert.")
else:
    print("That is too bad, your answer is incorrect. You lost a life..")
# Out:
# Is it true that Germany has the most power plants worldwide?
